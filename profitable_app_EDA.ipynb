# %% [markdown]
# # Exploratory Data Analysis of Profitable Apps in App Store and Google store
#
# The purpose of this project is to help developers understand what type of apps are likely to attract more users on Google Play and the App Store.

# %%
#Helper function for exploring the data
def explore_data(dataset, start, end, rows_and_columns=False):
    dataset_slice = dataset[start:end]
    for row in dataset_slice:
        print(row)
        print('\n')

    if rows_and_columns:
        print('Number of rows:', len(dataset))
        print('Number of columns:', len(dataset[0]))

# %% [markdown]
# Let us first open the datasets

# %%
from csv import reader

### Google Playstore Dataset ###
opened_file = open('./data/googleplaystore.csv', encoding='utf8')
read_file = reader(opened_file)
android = list(read_file)
android_header = android[0]
android = android[1:]

### Apple store Dataset ###
opened_file = open('./data/AppleStore.csv', encoding='utf8')
read_file = reader(opened_file)
ios = list(read_file)
ios_header = ios[0]
ios = ios[1:]

# %% [markdown]
# Let's check the Android data

# %%
print(android_header)
print('\n')
explore_data(android, 0, 5, True)
# Out:
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
#
#
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['Coloring book moana', 'ART_AND_DESIGN', '3.9', '967', '14M', '500,000+', 'Free', '0', 'Everyone', 'Art & Design;Pretend Play', 'January 15, 2018', '2.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']
#
#
# ['Pixel Draw - Number Art Coloring Book', 'ART_AND_DESIGN', '4.3', '967', '2.8M', '100,000+', 'Free', '0', 'Everyone', 'Art & Design;Creativity', 'June 20, 2018', '1.1', '4.4 and up']
#
#
# Number of rows: 10841
# Number of columns: 13

# %% [markdown]
# Checking the columns of the Google Play Store data, I think the useful features that can be helpful for our goal are the following: ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Android Ver']
#
# Removing the following coluns: ['Last Updated', 'Current Ver']

# %% [markdown]
# Now let's check the Apple data

# %%
print(ios_header)
print('\n')
explore_data(ios, 0, 5, True)
# Out:
# ['id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']
#
#
# ['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']
#
#
# ['389801252', 'Instagram', '113954816', 'USD', '0.0', '2161558', '1289', '4.5', '4.0', '10.23', '12+', 'Photo & Video', '37', '0', '29', '1']
#
#
# ['529479190', 'Clash of Clans', '116476928', 'USD', '0.0', '2130805', '579', '4.5', '4.5', '9.24.12', '9+', 'Games', '38', '5', '18', '1']
#
#
# ['420009108', 'Temple Run', '65921024', 'USD', '0.0', '1724546', '3842', '4.5', '4.0', '1.6.2', '9+', 'Games', '40', '5', '1', '1']
#
#
# ['284035177', 'Pandora - Music & Radio', '130242560', 'USD', '0.0', '1126879', '3594', '4.0', '4.5', '8.4.1', '12+', 'Music', '37', '4', '1', '1']
#
#
# Number of rows: 7197
# Number of columns: 16

# %%
# For easier referencing later
def header_indices(header):
    i = 0
    header_dict = {}
    while i < len(header):
        header_dict[header[i]] = i
        i += 1
    return header_dict

# %%
an_hi = header_indices(android_header)
ios_hi = header_indices(ios_header)

# %%
# Function for checking data completeness
def checkFeaturesIfComplete(dataset, column_headers):
  incomplete_found = False
  column_len = len(column_headers)
  for index, row in enumerate(dataset):
    if len(row) != column_len:
        print(index)
        print(row)
        incomplete_found = True
  if not incomplete_found:
    print('All dataset entry complete')

# %%
# Check the row if it has all columns
# Android
checkFeaturesIfComplete(android, android_header)
# Out:
# 10472
# ['Life Made WI-Fi Touchscreen Photo Frame', '1.9', '19', '3.0M', '1,000+', 'Free', '0', 'Everyone', '', 'February 11, 2018', '1.0.19', '4.0 and up']

# %%
len(android[10472])
# Out:
# 12

# %%
# For iOS
checkFeaturesIfComplete(ios, ios_header)
# Out:
# All dataset entry complete

# %% [markdown]
# One of the entry in Android only has 12 featrues instead of 13. Let's check what feature is missing then decide if it can be filled or just delete the entry.

# %%
print(android_header)
print(android[0])
print(android[10472])
# Out:
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
# ['Life Made WI-Fi Touchscreen Photo Frame', '1.9', '19', '3.0M', '1,000+', 'Free', '0', 'Everyone', '', 'February 11, 2018', '1.0.19', '4.0 and up']

# %% [markdown]
# It is missing the 'Category' feature which I think can be filled.

# %%
# Let's try to get all existing categories
categories = {row[1] for row in android}
print(categories)
# Out:
# {'COMMUNICATION', 'TRAVEL_AND_LOCAL', 'HOUSE_AND_HOME', 'SHOPPING', 'PHOTOGRAPHY', 'MEDICAL', 'MAPS_AND_NAVIGATION', 'ART_AND_DESIGN', 'COMICS', 'BOOKS_AND_REFERENCE', 'FAMILY', 'NEWS_AND_MAGAZINES', '1.9', 'BUSINESS', 'WEATHER', 'PERSONALIZATION', 'VIDEO_PLAYERS', 'DATING', 'BEAUTY', 'EVENTS', 'HEALTH_AND_FITNESS', 'TOOLS', 'GAME', 'EDUCATION', 'ENTERTAINMENT', 'LIBRARIES_AND_DEMO', 'SPORTS', 'PRODUCTIVITY', 'PARENTING', 'FINANCE', 'FOOD_AND_DRINK', 'LIFESTYLE', 'AUTO_AND_VEHICLES', 'SOCIAL'}

# %% [markdown]
# Based on the existing categories, it would fit the 'Photography' category.

# %%
android[10472].insert(1, 'PHOTOGRAPHY')
print(len(android[10472]))
print(android[10472])
# Out:
# 13
# ['Life Made WI-Fi Touchscreen Photo Frame', 'PHOTOGRAPHY', '1.9', '19', '3.0M', '1,000+', 'Free', '0', 'Everyone', '', 'February 11, 2018', '1.0.19', '4.0 and up']

# %% [markdown]
# Let us proceed to check if there are duplicate entries in our data.

# %%
# We make a set of app names to be compared with the number of data entries
apps = {row[an_hi['App']] for row in android}
print(f'Total app data: {len(android)}')
print(f'Unique app names: {len(apps)}')
print(f'App names: {apps}')
# Out:
# Total app data: 10841
# Unique app names: 9660
# App names: {'FollowMeter for Instagram', 'signály.cz', 'V for Vampire - Free', 'Talking Tom Gold Run', 'Real Gangster Crime', 'Alchemy Classic Ad Free', 'VZ Navigator', 'Education First FCU Mobile', 'F.A Sumon songs', 'CF Church', 'Brightest LED Flashlight', 'Florida Offline Road Map', 'Weight Loss Running by Verv', 'Free Wi-fi HotspoT', 'Indeed Job Search', 'Mini for fb lite', 'Wedding Countdown Widget', 'Dete.bg', 'VLC for Android', 'Home Decoration Game', 'BI-LO Rx', 'B.GOOD', 'European Solidarity Corps', 'Baby Food - Homemade Recipes', 'FIFA - Tournaments, Soccer News & Live Scores', 'Best CG Photography', 'reality.cz', 'Development of the child up to a year', 'ExDialer PRO Key', 'EK Bailey Preaching Conference', 'Citi Mobile®', 'The CW TN app 2018', 'The dollar in mexico', 'Gas Prices (Germany only)', 'EB Mobile', 'Flights', 'Asahi Shimbun Digital', 'Add-On: bq (c)', 'Easy Makeup Tutorials', 'Zowi App', 'WiFi FPV', 'Trane Interactive Smart AC', 'BBWCupid - BBW Dating App', 'Pint - FN Theme', 'Black Social', 'Diary with lock', 'Empire Z: Endless War', 'Pregnancy Tracker & Countdown to Baby Due Date', 'bz Basel News', 'Nursing Central', 'How To Color Disney Princess - Coloring Pages', 'S Photo Editor - Collage Maker , Photo Collage', 'Dulquer Salmaan HD Wallpapers', 'Bounce Classic', 'MelifeCam-M', 'iFORA BP', 'CP HAPPS - Pittsburgh Events', "HANGAME Casino - Baccarat & Texas Hold'em", 'Blood Pressure', 'Earth & Moon in HD Gyro 3D Parallax Live Wallpaper', 'Tubi TV - Free Movies & TV', 'DZ Popup Video Player', 'SCRABBLE', 'BT Speed', 'Doctors Care', 'Ocala Star Banner, FL', 'Mingle2 - Free Online Dating & Singles Chat Rooms', 'J - Style Pro', 'Photo Studio', 'CallApp: Caller ID, Blocker & Phone Call Recorder', 'HTC Sense Input-AR', 'Permit Test CO Colorado DMV', 'ZenUI Dialer & Contacts', 'GPS Map Free', 'Fuzzy Seasons: Animal Forest', 'POCKET BOOK CT ABDOMEN', 'Mali J', 'DC N COMPANY ENTERTAINMENT RADIO!', 'Open Heart Surgery Hospital ER: Crazy Doctor Sim', 'CTRL-F - Search the real world', 'Bowers & Wilkins DB Subwoofers', 'DF BugMeNot', 'Texas Holdem Poker Pro', 'Lux Home Decorating Room Games', 'AC Troubleshooter', 'Kung Fu Do Fighting', "PewDiePie's Tuber Simulator", 'dk', 'Home Workout for Men - Bodybuilding', 'Skip-Bo™', 'Crazy Colors: Bubbles Matching', 'Eyes - The Scary Horror Game Adventure', 'CB Pay', 'The Church at CW', 'dy n fly', 'DW Contacts Wear', 'Test de Inteligencia CI', 'Top Popular Ringtones 2018 Free 🔥', 'Florida Lottery Results', 'Hide App, Private Dating, Safe Chat - PrivacyHider', 'Name days', 'Deus Ex GO', 'Offroad Car H', 'Numerica CU', 'Jamaa Amino for Animal Jam', 'Herpes Positive Singles Dating', 'BF Scale Health Fitness Tool', 'At home - rental · real estate · room finding application such as apartment · apartment', 'DREAM-e: Dream Analysis A.I.', 'PLANK!', 'Dream EZ', 'Company Kitchen', 'Redwood CU v3.1.0', "Dr. Doug's Tips", 'Sway Medical', 'Sin City Crime Simulator V - Gangster', 'mySugr: the blood sugar tracker made just for you', 'gCMOB', 'Learning English for children', 'Auto Background Changer', 'AppClose - The #1 FREE Co-Parenting App', 'FK Sloboda Tuzla', 'Signal Spy - Monitor Signal Strength & Data Usage', 'Sat-Fi Voice', 'Display Phone Screen On TV', 'DaBang - Rental Homes in Korea', 'Money Manager Ex for Android', 'Free Slideshow Maker & Video Editor', 'Face Filter, Selfie Editor - Sweet Camera', 'OpenTable: Restaurants Near Me', 'BT One Voice anywhere', 'Rescue Robots Survival Games', 'Virtual Eye AI', 'Download Manager - File & Video', 'Citymapper - Transit Navigation', 'Dating Tips For Men', 'Learn Basic C - For Beginners', 'WISE- MOBILE PORTAL', 'Al-Quran (Free)', '.R', 'MetaTrader 5', 'Abs workout - 21 Day Fitness Challenge', 'Monster Ride Pro', 'HOW TO ASK A GIRL OUT', 'SAMURAI vs ZOMBIES DEFENSE', 'Beck & Bo: Toddler First Words', 'Super Hero M Craft Run', 'Eyewitness Travel Phrase Book', 'Messenger – Text and Video Chat for Free', 'Evernote – Organizer, Planner for Notes &  ...

# %%
# For iOS
ios_apps = {row[an_hi['App']] for row in ios}
print(f'Total app data: {len(ios)}')
print(f'Unique app names: {len(ios_apps)}')
print(f'App names: {ios_apps}')
# Out:
# Total app data: 7197
# Unique app names: 7197
# App names: {'463240522', '443932954', '447752317', '720111744', '313199385', '1085978097', '978148241', '1124467250', '957442616', '505728417', '741224931', '1097564743', '1067024404', '448474423', '434893913', '1076806233', '467329677', '414478124', '363590051', '929346489', '1149330452', '409605521', '947624478', '918820076', '1075820557', '917912662', '431946152', '1100160696', '1055925081', '1099021080', '659425518', '952694580', '1112052555', '1105790805', '1142546565', '944646397', '1079316669', '635966718', '944644383', '354974729', '639930688', '1107741196', '1161231636', '398954883', '606910110', '1057844059', '1086539327', '1066769531', '875063456', '973741088', '491075156', '963034692', '1111876388', '823869162', '1034591399', '284815117', '1068808996', '891294826', '1054033219', '1151562012', '925242723', '1084253570', '882365789', '1164891129', '1063191689', '946811576', '891528055', '835731296', '1006393168', '1100139790', '1031867079', '1005783927', '829581836', '885823239', '1038849525', '1072159054', '1181025437', '627994145', '561625752', '883997728', '725097967', '1169971902', '1062168249', '476555713', '997252057', '1178880179', '1034774337', '1028950091', '1044341430', '1144446958', '1060443742', '948090890', '502803489', '1093108529', '796851829', '721623681', '445338486', '922281347', '530001625', '1116609570', '830515294', '923268741', '988737164', '1161175470', '804637783', '1071633581', '960504959', '283619399', '482669234', '1006385486', '1048018108', '366869252', '1034399175', '923814895', '885271158', '971265422', '935559685', '918138802', '297368629', '977965019', '711923939', '1078812538', '468401854', '1011661714', '953831664', '1004090290', '1073166647', '834248867', '686542963', '838848566', '662090840', '749113886', '1164046790', '1161496947', '866786833', '1181526812', '678861146', '557121061', '459035295', '1147432809', '1130901077', '1178454068', '1118082679', '1126723825', '795739546', '538248967', '1162719828', '1094177277', '993605516', '1085458374', '964064306', '1150981743', '988235692', '951417499', '1084644256', '1134424698', '499794670', '1141834022', '539124565', '1047042828', '1064304763', '1185538497', '451584035', '595098366', '427419772', '528919633', '645705454', '1151423446', '974135847', '1130829481', '1094930513', '1046884557', '1175770622', '477537958', '1135441810', '970416885', '1163850915', '1068596150', '834854351', '1142385805', '1116880272', '1156704617', '1095571204', '1127634439', '1003837100', '594145971', '515651240', '934596429', '474764934', '485126024', '1040451375', '920133658', '608847384', '1037781582', '1130186793', '570306657', '1031228862', '1012298403', '555590884', '525929300', '596677177', '708142626', '997446291', '950984120', '1163372874', '284666222', '1082150954', '912536422', '578665578', '897447840', '566199224', '381471023', '631073589', '1159611436', '1047605171', '962967653', '950574221', '1048896882', '1059401746', '1024951639', '1115022026', '495680460', '485534181', '987868589', '967181200', '486154808', '951536298', '515850648', '586280100', '530425820', '1157626939', '1110447884', '869231055', '923917775', '721911537', '505066327', '529652920', '1140495295', '1058786785', '963668030', '646619812', '1032845453', '1120339123', '1027230451', '911156590', '1136538547', '1002317411', '1045947023', '1044318857', '1028610115', '1159900476', '1020947824', '1115010672', '527219710', '863844475', '645384141', '896890211', '977354430', '1106808184', '1118878857', '971233157', '400971700', '1061661355', '1011415692', '1097737340', '1142578005', '953923489', '410315894', '1171367187', '1066752474', '1042299727', '1174999653', '1011479119', '873008064', '673120263', '1000559499', '1169836224', '521640355', '1100810556', '1127108818', '1065754566', '436491861', '571393580', '398166286', '1086917828', '733144873', '1039971485', '462125072', '398860966', '805869467', '909911026', '906995758', '735434007', '749109884', '528805631', '1022267439', '6341587 ...

# %% [markdown]
# For the case of the iOS apps, there are no duplicates.
# Based on the results of our code above for Android apps, there are 1181 cases of apps occuring more than once.
# Let's take a look at one of the apps with duplicate entry.

# %%
app_histogram = {}
for row in android:
  name = row[0]
  if name in app_histogram:
    app_histogram[name] += 1
  else:
    app_histogram[name] = 1
print(app_histogram)
# Out:
# {'Photo Editor & Candy Camera & Grid & ScrapBook': 1, 'Coloring book moana': 2, 'U Launcher Lite – FREE Live Cool Themes, Hide Apps': 1, 'Sketch - Draw & Paint': 1, 'Pixel Draw - Number Art Coloring Book': 1, 'Paper flowers instructions': 1, 'Smoke Effect Photo Maker - Smoke Editor': 1, 'Infinite Painter': 1, 'Garden Coloring Book': 1, 'Kids Paint Free - Drawing Fun': 1, 'Text on Photo - Fonteee': 1, 'Name Art Photo Editor - Focus n Filters': 1, 'Tattoo Name On My Photo Editor': 1, 'Mandala Coloring Book': 1, '3D Color Pixel by Number - Sandbox Art Coloring': 1, 'Learn To Draw Kawaii Characters': 1, 'Photo Designer - Write your name with shapes': 1, '350 Diy Room Decor Ideas': 1, 'FlipaClip - Cartoon animation': 1, 'ibis Paint X': 1, 'Logo Maker - Small Business': 1, "Boys Photo Editor - Six Pack & Men's Suit": 1, 'Superheroes Wallpapers | 4K Backgrounds': 1, 'Mcqueen Coloring pages': 2, 'HD Mickey Minnie Wallpapers': 1, 'Harley Quinn wallpapers HD': 1, 'Colorfit - Drawing & Coloring': 1, 'Animated Photo Editor': 1, 'Pencil Sketch Drawing': 1, 'Easy Realistic Drawing Tutorial': 1, 'Pink Silver Bow Keyboard Theme': 1, 'Art Drawing Ideas': 1, 'Anime Manga Coloring Book': 1, 'Easy Origami Ideas': 1, 'I Creative Idea': 1, 'How to draw Ladybug and Cat Noir': 1, 'UNICORN - Color By Number & Pixel Art Coloring': 2, 'Floor Plan Creator': 1, 'PIP Camera - PIP Collage Maker': 1, 'How To Color Disney Princess - Coloring Pages': 1, 'Drawing Clothes Fashion Ideas': 1, 'Sad Poetry Photo Frames 2018': 1, 'Textgram - write on photos': 2, 'Paint Splash!': 1, 'Popsicle Sticks and Similar DIY Craft Ideas': 1, 'Canva: Poster, banner, card maker & graphic design': 1, 'Install images with music to make video without Net - 2018': 1, 'Little Teddy Bear Colouring Book Game': 1, 'How To Draw Food': 1, 'Monster Truck Stunt 3D 2019': 1, 'Real Tractor Farming': 1, 'Ultimate F1 Racing Championship': 1, 'Used Cars and Trucks for Sale': 1, 'American Muscle Car Race': 1, 'Offroad Oil Tanker Driver Transport Truck 2019': 1, 'Tickets SDA 2018 and Exam from the State Traffic Safety Inspectorate with Drom.ru': 1, 'Gas Prices (Germany only)': 1, 'Extreme Rally Championship': 1, 'Restart Navigator': 1, 'REG - Check the regnumber, find information about Swedish vehicles': 1, 'CityBus Lviv': 1, 'CDL Practice Test 2018 Edition': 1, 'ezETC (ETC balance inquiry, meter trial, real-time traffic)': 1, 'Free VIN Report for Used Cars': 1, 'DMV Permit Practice Test 2018 Edition': 1, 'Check Vehicle Tax': 1, 'Used Cars Mexico': 1, 'Ulysse Speedometer': 1, 'REPUVE': 1, 'Used cars for sale - Trovit': 1, 'Fines of the State Traffic Safety Inspectorate are official: inspection, payment of fines': 1, 'SK Enca Direct Malls - Used Cars Search': 1, 'Android Auto - Maps, Media, Messaging & Voice': 1, 'PDD-UA': 1, 'Tickets SDA 2019 + Exam RF': 1, 'Super Cars Wallpapers And Backgrounds': 1, 'Police Lights, Sirens & Follow Me': 1, 'Police Detector (Speed Camera Radar)': 1, 'Best Car Wallpapers': 1, 'Tickets + PDA 2018 Exam': 1, 'Pick Your Part Garage': 1, 'PakWheels: Buy & Sell Cars': 1, 'Supervision service': 1, 'Speed Camera Detector - Traffic & Speed Alert': 1, 'Used car search Goo net whole car Go to net': 1, 'CarMax – Cars for Sale: Search Used Car Inventory': 1, 'BEST CAR SOUNDS': 1, 'RST - Sale of cars on the PCT': 1, 'AutoScout24 Switzerland – Find your new car': 1, 'Zona Azul Digital Fácil SP CET - OFFICIAL São Paulo': 1, 'SMS Park': 1, 'SKencar': 1, 'Fuelio: Gas log & costs': 1, 'auto fines': 1, 'Used car is the first car - used car purchase, used car quotation, dealer information to': 1, 'All of the parking lot - National Park application (parking lot search / parking sharing / discount payment)': 1, 'Inquiry Fines and Debits of Vehicles': 1, 'Gas Station': 1, 'Hush - Beauty for Everyone': 1, 'ipsy: Makeup, Beauty, and Tips': 1, 'Natural recipes for your beauty': 1, 'BestCam Selfie-selfie, beauty camera, photo editor': 1, 'Mirror - Zoom & Exposure -': 1, 'Beauty Selfie Camera':  ...

# %%
for name, count in app_histogram.items():
  if count > 2:
    print(f'{name}, {count}')
# Out:
# Google My Business, 3
# Box, 3
# Quick PDF Scanner + OCR FREE, 3
# Google Ads, 3
# Slack, 3
# QuickBooks Accounting: Invoicing & Expenses, 3
# join.me - Simple Meetings, 3
# Messenger – Text and Video Chat for Free, 3
# WhatsApp Messenger, 3
# Google Chrome: Fast & Secure, 3
# Gmail, 3
# Hangouts, 4
# Viber Messenger, 5
# Firefox Browser fast & private, 3
# Yahoo Mail – Stay Organized, 3
# imo free video calls and chat, 4
# Opera Mini - fast web browser, 3
# Opera Browser: Fast and Secure, 3
# Firefox Focus: The privacy browser, 3
# Google Voice, 3
# WeChat, 4
# UC Browser Mini -Tiny Fast Private & Secure, 3
# Telegram, 3
# Puffin Web Browser, 3
# UC Browser - Fast Download Private & Secure, 3
# free video calls and chat, 3
# Skype - free IM & video calls, 3
# Google Allo, 3
# LINE: Free Calls & Messages, 3
# KakaoTalk: Free Calls & Text, 3
# OkCupid Dating, 3
# Hily: Dating, Chat, Match, Meet & Hook up, 3
# BBW Dating & Plus Size Chat, 3
# Moco - Chat, Meet People, 3
# Hot or Not - Find someone right now, 3
# Just She - Top Lesbian Dating, 3
# muzmatch: Muslim & Arab Singles, Marriage & Dating, 3
# Adult Dirty Emojis, 3
# O-Star, 3
# Duolingo: Learn Languages Free, 7
# TED, 4
# Khan Academy, 3
# Babbel – Learn Languages, 4
# Learn languages, grammar & vocabulary with Memrise, 4
# Quizlet: Learn Languages & Vocab with Flashcards, 4
# Udemy - Online Courses, 3
# Rosetta Stone: Learn to Speak & Read New Languages, 4
# Google Classroom, 3
# busuu: Learn Languages - Spanish, English & More, 4
# ClassDojo, 3
# Netflix, 5
# Tubi TV - Free Movies & TV, 3
# YouTube Kids, 4
# Viki: Asian TV Dramas & Movies, 3
# Movies by Flixster, with Rotten Tomatoes, 3
# IMDb Movies & TV, 3
# Food Network, 3
# Crunchyroll - Everything Anime, 3
# Crackle - Free TV & Movies, 3
# STARZ, 3
# HISTORY: Watch TV Show Full Episodes & Specials, 3
# Nick, 6
# VH1, 3
# FOX NOW - On Demand & Live TV, 3
# A&E - Watch Full Episodes of TV Shows, 4
# The CW, 4
# BET NOW - Watch Shows, 3
# Hulu: Stream TV, Movies & more, 4
# HBO NOW: Stream TV & Movies, 4
# Lifetime - Watch Full Episodes & Original Movies, 3
# Credit Karma, 3
# Google Pay, 4
# Mint: Budget, Bills, Finance, 3
# Chick-fil-A, 3
# Runtastic Running App & Mile Tracker, 3
# Nike+ Run Club, 4
# Calorie Counter - MyFitnessPal, 5
# Weight Watchers Mobile, 3
# Run with Map My Run, 3
# Weight Loss Running by Verv, 3
# Nike Training Club - Workouts & Fitness Plans, 3
# Daily Yoga - Yoga Fitness Plans, 3
# Lose It! - Calorie Counter, 3
# Houzz Interior Design Ideas, 4
# Fashion in Vogue, 3
# ROBLOX, 9
# Subway Surfers, 6
# Candy Crush Saga, 7
# Solitaire, 3
# Bubble Shooter, 6
# slither.io, 6
# Clash Royale, 4
# Temple Run 2, 6
# Pou, 4
# Helix Jump, 6
# Block Puzzle, 4
# Angry Birds Rio, 4
# Plants vs. Zombies FREE, 5
# Candy Crush Soda Saga, 3
# Zombie Hunter King, 4
# Clash of Clans, 4
# Kick the Buddy, 4
# Super Jim Jump - pixel 3d, 3
# 8 Ball Pool, 7
# Magic Tiles 3, 4
# Word Search, 4
# Granny, 5
# Angry Birds Classic, 5
# Flow Free, 5
# Fishdom, 3
# Galaxy Attack: Alien Shooter, 3
# Zombie Tsunami, 5
# Hill Climb Racing, 4
# Zombie Catchers, 6
# Minion Rush: Despicable Me Official Game, 4
# Farm Heroes Saga, 5
# My Talking Angela, 4
# Cut the Rope FULL FREE, 3
# Sniper 3D Gun Shooter: Free Shooting Games - FPS, 6
# Toon Blast, 3
# Score! Hero, 3
# Miraculous Ladybug & Cat Noir - The Official Game, 3
# Wordscapes, 4
# Garena Free Fire, 4
# Bowmasters, 6
# My Talking Tom, 3
# Talking Tom Gold Run, 4
# Pixel Art: Color by Number Game, 3
# Dream League Soccer 2018, 3
# Block Craft 3D: Building Simulator Games For Free, 3
# Hungry Shark Evolution, 3
# PUBG MOBILE, 4
# MARVEL Strike Force, 3
# DRAGON BALL LEGENDS, 4
# Strawberry Shortcake BerryRush, 3
# DC Super Hero Girls™, 4
# Dog Run - Pet Dog Simulator, 3
# Toca Kitchen 2, 3
# PJ Masks: Moonlight Heroes, 3
# DisneyNOW – TV Shows & Games, 3
# Papumba Academy - Fun Learning For Kids, 3
# Equestria Girls, 3
# Frozen Free Fall, 3
# Elmo Calls by Sesame Street, 3
# Sago Mini Friends, 3
# Dr. Panda & Toto's Treehouse, 3
# Video Editor, 3
# Human Anatomy Atlas 2018: Complete 3D Human Body, 3
# Cardiac diagnosis (heart rate, arrhythmia), 3
# Blood Pressure, 3
# Youper - AI Therapy, 3
# mySugr: the blood sugar tracker made just for you, 3
# Free Blood Pressure, 3
# Instagram, 4
# Tumblr, 3
# Snapchat, 4
# Pinterest, 3
# Periscope - Live Video, 3
# Meetup, 4
# Text Free: WiFi Calling App, 3
# Badoo - Free Chat & Dating App, 4
# MeetMe: Chat & Meet New People, 5
# SayHi Chat, Meet New People, 3
# POF Free Dating App, 3
# Wish - Shopping Made Fun, 5
# AliExpress - Smarter Shopping, Better Living, 4
# eBay: Buy & Sell this Summer - Discover Deals Now!, 5
# Amazon Shopping, 3
# Target - now with Cartwheel, 3
# Extreme Coupon Finder, 3
# Checkout 51: Grocery coupons, 3
# Gyft - Mobile Gift Card Wallet, 3
# The Coupons App, 4
# RetailMeNot - Coupons, Deals & Discount Shopping, 3
# Groupon - Shop Deals, Discounts & Coupons, 4
# LivingSocial - Local Deals, 3
# Fancy, 3
# JackThreads: Men's Shopping, 3
# Slickdeals: Coupons & Shopping, 3
# Shutterfly: Free Prints, Photo Books, Cards, Gifts, 4
# Google Photos, 4
# B612 - Beauty & Filter Camera, 3
# BeautyPlus - Easy Photo Editor & Selfie Camera, 5
# YouCam Perfect - Selfie Photo Editor, 3
# Open Camera, 3
# QuickPic - Photo Gallery with Google Drive Support, 3
# Camera for Android, 3
# Cymera Camera- Photo Editor, Filter,Collage,Layout, 4
# Candy Camera - selfie, beauty camera, photo editor, 3
# Camera360: Selfie Photo Editor with Funny Sticker, 3
# Facetune - For Free, 3
# ESPN, 7
# MLB At Bat, 5
# NFL, 3
# theScore: Live Sports Scores, News, Stats & Videos, 5
# Yahoo Fantasy Sports - #1 Rated Fantasy App, 5
# CBS Sports App - Scores, News, Stats & Watch Live, 8
# ESPN Fantasy Sports, 4
# Bleacher Report: sports news, scores, & highlights, 6
# WatchESPN, 4
# Yahoo Sports - scores, stats, news, & highlights, 3
# Expedia Hotels, Flights & Car Rental Travel Deals, 4
# trivago: Hotels & Travel, 3
# KAYAK Flights, Hotels & Cars, 3
# Skyscanner, 5
# Booking.com Travel Deals, 3
# TripAdvisor Hotels Flights Restaurants Attractions, 5
# Maps - Navigate & Explore, 3
# Priceline Hotel Deals, Rental Cars & Flights, 3
# American Airlines, 3
# HotelTonight: Book amazing deals at great hotels, 3
# Gboard - the Google Keyboard, 3
# ZEDGE™ Ringtones & Wallpapers, 4
# Apex Launcher, 3
# Microsoft Word, 3
# Adobe Acrobat Reader, 3
# Google Drive, 4
# Google PDF Viewer, 3
# Microsoft OneNote, 3
# Google Keep, 4
# ES File Explorer File Manager, 3
# Dropbox, 3
# Google Calendar, 3
# Google Docs, 3
# Evernote – Organizer, Planner for Notes & Memos, 4
# Wunderlist: To-Do List & Tasks, 3
# Todoist: To-do lists for task management & errands, 3
# Any.do: To-do list, Calendar, Reminders & Planner, 3
# MX Player, 3
# Fox News – Breaking News, Live Video & News Alerts, 3
# BBC News, 3
# CNN Breaking US & World News, 3
# Google News, 4
# Twitter, 3
# Flipboard: News For Our Time, 3
# USA TODAY, 3
# NYTimes - Latest News, 3

# %%
print(android_header)
for app in android:
  name = app[0]
  if name == 'WeChat':
    print(app)
# Out:
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['WeChat', 'COMMUNICATION', '4.2', '5387333', 'Varies with device', '100,000,000+', 'Free', '0', 'Everyone', 'Communication', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['WeChat', 'COMMUNICATION', '4.2', '5387446', 'Varies with device', '100,000,000+', 'Free', '0', 'Everyone', 'Communication', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['WeChat', 'COMMUNICATION', '4.2', '5387446', 'Varies with device', '100,000,000+', 'Free', '0', 'Everyone', 'Communication', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['WeChat', 'COMMUNICATION', '4.2', '5387631', 'Varies with device', '100,000,000+', 'Free', '0', 'Everyone', 'Communication', 'July 31, 2018', 'Varies with device', 'Varies with device']

# %% [markdown]
# Inspecting the data of the duplicate entries for WeChat, they differ on the 4th column which represents the number of reviews. This could indicate that data was collected at different times.
# With this information, we can use it as a criterion for removing the duplicate entries. We will only keep the entry with the highest review count which indicates that it is the latest entry.

# %%
import time
t1 = time.time()

# For the first part, we create a dictionary of apps with its highest review count
reviews_max = {}

for row in android:
  name = row[an_hi['App']]
  review_count = int(row[an_hi['Reviews']])
  if name not in reviews_max:
    reviews_max[name] = review_count
  else:
    reviews_max[name] = review_count if review_count > reviews_max[name] else reviews_max[name]

print(len(reviews_max))

android_clean = []
added_app = set()
for row in android:
  name = row[an_hi['App']]
  review_count = int(row[an_hi['Reviews']])
  if review_count == reviews_max[name] and name not in added_app:
    android_clean.append(row)
    added_app.add(name)

t2 = time.time()
print("Time taken: %.6f" %(t2 - t1))
print(f'Expected length: 9660, Actual: {len(android_clean)}')
# Out:
# 9660
# Time taken: 0.014519
# Expected length: 9660, Actual: 9660

# %% [markdown]
# Let us now proceed with removing non-English apps

# %%
print(ios[813][1])
print(ios[6731][1])
print(android_clean[4412][0])
print(android_clean[7940][0])
# Out:
# 爱奇艺PPS -《欢乐颂2》电视剧热播
# 【脱出ゲーム】絶対に最後までプレイしないで 〜謎解き＆ブロックパズル〜
# 中国語 AQリスニング
# لعبة تقدر تربح DZ

# %% [markdown]
# Each character we use in a string has a corresponding number associated with it. The characters commonly used in an English text are all in the range of 0 to 127. With this information we can write a function to check if a character's numeric code lies within 0 to 127.

# %%
def isEnglish(name):
  #Use the ord function to get the corresponding number of a character
  for letter in name:
    if ord(letter) > 127:
      return False
  return True

# %% [markdown]
# Let's try it out with a few samples
# - 'Instagram'
# - '爱奇艺PPS -《欢乐颂2》电视剧热播'
# - 'Docs To Go™ Free Office Suite'
# - 'Instachat 😜'

# %%
print(isEnglish('Instagram'))
print(isEnglish('爱奇艺PPS -《欢乐颂2》电视剧热播'))
print(isEnglish('Docs To Go™ Free Office Suite'))
print(isEnglish('Instachat 😜'))
# Out:
# True
# False
# False
# False

# %% [markdown]
# The last 2 apps gets rejected because of the special characters. Let's try to update the function to handle these cases.

# %%
def isEnglishV2(name):
  #Use the ord function to get the corresponding number of a character
  #Create a counter for non-English characters
  special_count = 0
  for letter in name:
    if ord(letter) > 127:
      special_count += 1
    # If the count of special character exceeds 3, it should be considered as non-english
    if special_count > 3:
      return False
  return True

# %%
print(isEnglishV2('Instagram'))
print(isEnglishV2('爱奇艺PPS -《欢乐颂2》电视剧热播'))
print(isEnglishV2('Docs To Go™ Free Office Suite'))
print(isEnglishV2('Instachat 😜'))
# Out:
# True
# False
# True
# True

# %% [markdown]
# The function seems to work well, let's try it on the dataset and see how many gets filtered out.

# %%
# Android apps
print(f'Original Android data count: {len(android_clean)}')

android_clean_eng = []
for row in android_clean:
  name = row[an_hi['App']]
  if isEnglishV2(name):
    android_clean_eng.append(row)

# iOS apps
print(f'Original iOS data count: {len(ios)}')

ios_clean_eng = []
for row in ios:
  name = row[1]
  if isEnglishV2(name):
    ios_clean_eng.append(row)

print(f'Remaining Android app: {len(android_clean_eng)}')
print(f'Remaining iOS app: {len(ios_clean_eng)}')
# Out:
# Original Android data count: 9660
# Original iOS data count: 7197
# Remaining Android app: 9615
# Remaining iOS app: 6183

# %% [markdown]
# The amount of filtered out apps looks aceptable and we still have plenty of data.

# %% [markdown]
# We will now to proceed to select only the free apps.

# %%
print(an_hi)
print(ios_hi)
# Out:
# {'App': 0, 'Category': 1, 'Rating': 2, 'Reviews': 3, 'Size': 4, 'Installs': 5, 'Type': 6, 'Price': 7, 'Content Rating': 8, 'Genres': 9, 'Last Updated': 10, 'Current Ver': 11, 'Android Ver': 12}
# {'id': 0, 'track_name': 1, 'size_bytes': 2, 'currency': 3, 'price': 4, 'rating_count_tot': 5, 'rating_count_ver': 6, 'user_rating': 7, 'user_rating_ver': 8, 'ver': 9, 'cont_rating': 10, 'prime_genre': 11, 'sup_devices.num': 12, 'ipadSc_urls.num': 13, 'lang.num': 14, 'vpp_lic': 15}

# %%
# Lets check for apps with price listed as 'Free' or '0.0'
android_clean_eng_free = []
for row in android_clean_eng:
  price = row[an_hi['Price']]
  if price.lower() == 'free' or price == '0' or price == '0.0':
    android_clean_eng_free.append(row)

# %%
print(f'Android Clean Eng: {len(android_clean_eng)}')
print(f'Android Clean Eng Free: {len(android_clean_eng_free)}')
print(f'Difference: {len(android_clean_eng)-len(android_clean_eng_free)}')
# Out:
# Android Clean Eng: 9615
# Android Clean Eng Free: 8865
# Difference: 750

# %% [markdown]
# 750 apps were removed from the android dataset.

# %%
# Lets check for apps for iOS with price listed as 'Free' or '0.0'
ios_clean_eng_free = []
for row in ios_clean_eng:
  price = row[ios_hi['price']]
  if price.lower() == 'free' or price == '0' or price == '0.0':
    ios_clean_eng_free.append(row)

# %%
print(f'iOS Clean Eng: {len(ios_clean_eng)}')
print(f'iOS Clean Eng Free: {len(ios_clean_eng_free)}')
print(f'Difference: {len(ios_clean_eng)-len(ios_clean_eng_free)}')
# Out:
# iOS Clean Eng: 6183
# iOS Clean Eng Free: 3222
# Difference: 2961

# %% [markdown]
# Almost half of the data for iOS was lost. Let's check further to confirm.

# %%
free_count = 0
for row in ios_clean_eng:
  price = row[ios_hi['price']]
  if price.lower() == 'free' or price == '0' or price == '0.0':
    free_count+=1
print(free_count)
# Out:
# 3222

# %% [markdown]
# Manually inspecting the dataset, it majority of the iOS apps in the dataset are not free, so I think we can proceed with what we have left.

# %% [markdown]
# ## Analysis
# Now that our data is clean, we may now proceed with the analysis. Our goal is to identify app profiels that are successful in both markets, because the number of people using our apps affect our revenue.
# <br>
# To minimize risks and overhead, our validation strategy for an app idea has three steps:
# 1. Build a minimal Android version of the app, and add it to Google Play
# 2. If the app has a good response from users, we develop it further
# 3. If the app is profitable after 6 months, we build an iOS version of the app and add it to the App Store
# <br>
# > The reason for publishing first in Android is that it's free.

# %% [markdown]
# Will first try to select the columns which can be useful to generate a frequency table. On our dataset, it can be `genre` or `category` for the Android dataset and `prime_genre` for iOS dataset.

# %%
print(ios_header)
print('\n')
explore_data(ios_clean_eng_free, 0, 5, True)
# Out:
# ['id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']
#
#
# ['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']
#
#
# ['389801252', 'Instagram', '113954816', 'USD', '0.0', '2161558', '1289', '4.5', '4.0', '10.23', '12+', 'Photo & Video', '37', '0', '29', '1']
#
#
# ['529479190', 'Clash of Clans', '116476928', 'USD', '0.0', '2130805', '579', '4.5', '4.5', '9.24.12', '9+', 'Games', '38', '5', '18', '1']
#
#
# ['420009108', 'Temple Run', '65921024', 'USD', '0.0', '1724546', '3842', '4.5', '4.0', '1.6.2', '9+', 'Games', '40', '5', '1', '1']
#
#
# ['284035177', 'Pandora - Music & Radio', '130242560', 'USD', '0.0', '1126879', '3594', '4.0', '4.5', '8.4.1', '12+', 'Music', '37', '4', '1', '1']
#
#
# Number of rows: 3222
# Number of columns: 16

# %%
print(android_header)
print('\n')
explore_data(android_clean_eng_free, 0, 5, True)
# Out:
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
#
#
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']
#
#
# ['Pixel Draw - Number Art Coloring Book', 'ART_AND_DESIGN', '4.3', '967', '2.8M', '100,000+', 'Free', '0', 'Everyone', 'Art & Design;Creativity', 'June 20, 2018', '1.1', '4.4 and up']
#
#
# ['Paper flowers instructions', 'ART_AND_DESIGN', '4.4', '167', '5.6M', '50,000+', 'Free', '0', 'Everyone', 'Art & Design', 'March 26, 2017', '1.0', '2.3 and up']
#
#
# Number of rows: 8865
# Number of columns: 13

# %%
# Create a frequency table
def freq_table(dataset, column_index):
  frequency_table = {}
  total = 0
  for row in dataset:
    total += 1
    key = row[column_index]
    if key in frequency_table:
      frequency_table[key] += 1
    else:
      frequency_table[key] = 1
  
  table_percentages = {}
  for key in frequency_table:
    percentage = (frequency_table[key]/total) * 100
    table_percentages[key] = percentage

  return table_percentages

def display_table(dataset, column_index):
  table = freq_table(dataset, column_index)
  table_display = []
  for key in table:
    key_val_as_tuple = (table[key], key)
    table_display.append(key_val_as_tuple)

  table_sorted = sorted(table_display, reverse=True)
  for entry in table_sorted:
    print(f'{entry[1]}: {entry[0]}')

# %%
android_final = android_clean_eng_free
ios_final = ios_clean_eng_free

# %%
display_table(android_final, an_hi['Genres'])
# Out:
# Tools: 8.44895657078398
# Entertainment: 6.068809926677947
# Education: 5.346869712351946
# Business: 4.591088550479413
# Productivity: 3.8917089678511
# Lifestyle: 3.8917089678511
# Finance: 3.699943598420756
# Medical: 3.5307388606880994
# Sports: 3.4630569655950363
# Personalization: 3.3164128595600673
# Communication: 3.2374506486181613
# Action: 3.102086858432036
# Health & Fitness: 3.0795262267343486
# Photography: 2.9441624365482233
# News & Magazines: 2.7975183305132543
# Social: 2.662154540327129
# Travel & Local: 2.323745064861816
# Shopping: 2.2447828539199097
# Books & Reference: 2.143260011280316
# Simulation: 2.0417371686407217
# Dating: 1.8612521150592216
# Arcade: 1.849971799210378
# Video Players & Editors: 1.7710095882684715
# Casual: 1.7597292724196276
# Maps & Navigation: 1.3987591652566271
# Food & Drink: 1.2408347433728144
# Puzzle: 1.1280315848843767
# Racing: 0.9926677946982515
# Role Playing: 0.9362662154540328
# Libraries & Demo: 0.9362662154540328
# Auto & Vehicles: 0.924985899605189
# Strategy: 0.9137055837563453
# House & Home: 0.8234630569655951
# Weather: 0.8009024252679076
# Events: 0.7106598984771574
# Adventure: 0.676818950930626
# Comics: 0.6091370558375634
# Beauty: 0.5978567399887197
# Art & Design: 0.5978567399887197
# Parenting: 0.49633389734912575
# Card: 0.4512126339537508
# Casino: 0.42865200225606315
# Trivia: 0.4173716864072194
# Educational;Education: 0.39481105470953193
# Board: 0.3835307388606881
# Educational: 0.3722504230118443
# Education;Education: 0.338409475465313
# Word: 0.25944726452340666
# Casual;Pretend Play: 0.23688663282571912
# Music: 0.20304568527918782
# Racing;Action & Adventure: 0.1692047377326565
# Puzzle;Brain Games: 0.1692047377326565
# Entertainment;Music & Video: 0.1692047377326565
# Casual;Brain Games: 0.1353637901861252
# Casual;Action & Adventure: 0.1353637901861252
# Arcade;Action & Adventure: 0.12408347433728144
# Action;Action & Adventure: 0.10152284263959391
# Educational;Pretend Play: 0.09024252679075014
# Simulation;Action & Adventure: 0.07896221094190638
# Parenting;Education: 0.07896221094190638
# Entertainment;Brain Games: 0.07896221094190638
# Board;Brain Games: 0.07896221094190638
# Parenting;Music & Video: 0.0676818950930626
# Educational;Brain Games: 0.0676818950930626
# Casual;Creativity: 0.0676818950930626
# Art & Design;Creativity: 0.0676818950930626
# Education;Pretend Play: 0.05640157924421885
# Role Playing;Pretend Play: 0.04512126339537507
# Education;Creativity: 0.04512126339537507
# Role Playing;Action & Adventure: 0.0338409475465313
# Puzzle;Action & Adventure: 0.0338409475465313
# Entertainment;Creativity: 0.0338409475465313
# Entertainment;Action & Adventure: 0.0338409475465313
# Educational;Creativity: 0.0338409475465313
# Educational;Action & Adventure: 0.0338409475465313
# Education;Music & Video: 0.0338409475465313
# Education;Brain Games: 0.0338409475465313
# Education;Action & Adventure: 0.0338409475465313
# Adventure;Action & Adventure: 0.0338409475465313
# Video Players & Editors;Music & Video: 0.022560631697687534
# Sports;Action & Adventure: 0.022560631697687534
# Simulation;Pretend Play: 0.022560631697687534
# Puzzle;Creativity: 0.022560631697687534
# Music;Music & Video: 0.022560631697687534
# Entertainment;Pretend Play: 0.022560631697687534
# Casual;Education: 0.022560631697687534
# Board;Action & Adventure: 0.022560631697687534
# Video Players & Editors;Creativity: 0.011280315848843767
# Trivia;Education: 0.011280315848843767
# Travel & Local;Action & Adventure: 0.011280315848843767
# Tools;Education: 0.011280315848843767
# Strategy;Education: 0.011280315848843767
# Strategy;Creativity: 0.011280315848843767
# Strategy;Action & Adventure: 0.011280315848843767
# Simulation;Education: 0.011280315848843767
# Role Playing;Brain Games: 0.011280315848843767
# Racing;Pretend Play: 0.011280315848843767
# Puzzle;Education: 0.011280315848843767
# Parenting;Brain Games: 0.011280315848843767
# Music & Audio;Music & Video: 0.011280315848843767
# Lifestyle;Pretend Play: 0.011280315848843767
# Lifestyle;Education: 0.011280315848843767
# Health & Fitness;Education: 0.011280315848843767
# Health & Fitness;Action & Adventure: 0.011280315848843767
# Entertainment;Education: 0.011280315848843767
# Communication;Creativity: 0.011280315848843767
# Comics;Creativity: 0.011280315848843767
# Casual;Music & Video: 0.011280315848843767
# Card;Action & Adventure: 0.011280315848843767
# Books & Reference;Education: 0.011280315848843767
# Art & Design;Pretend Play: 0.011280315848843767
# Art & Design;Action & Adventure: 0.011280315848843767
# Arcade;Pretend Play: 0.011280315848843767
# Adventure;Education: 0.011280315848843767
# : 0.011280315848843767

# %% [markdown]
# In the Android dataset, the most common genre is Tools followed by Entertainment. It is noticable from the table is that it's granular and the difference between each genre is just small.

# %%
display_table(android_final, an_hi['Category'])
# Out:
# FAMILY: 18.905809362662154
# GAME: 9.723632261703328
# TOOLS: 8.460236886632826
# BUSINESS: 4.591088550479413
# LIFESTYLE: 3.902989283699944
# PRODUCTIVITY: 3.8917089678511
# FINANCE: 3.699943598420756
# MEDICAL: 3.5307388606880994
# SPORTS: 3.395375070501974
# PERSONALIZATION: 3.3164128595600673
# COMMUNICATION: 3.2374506486181613
# HEALTH_AND_FITNESS: 3.0795262267343486
# PHOTOGRAPHY: 2.955442752397067
# NEWS_AND_MAGAZINES: 2.7975183305132543
# SOCIAL: 2.662154540327129
# TRAVEL_AND_LOCAL: 2.33502538071066
# SHOPPING: 2.2447828539199097
# BOOKS_AND_REFERENCE: 2.143260011280316
# DATING: 1.8612521150592216
# VIDEO_PLAYERS: 1.793570219966159
# MAPS_AND_NAVIGATION: 1.3987591652566271
# FOOD_AND_DRINK: 1.2408347433728144
# EDUCATION: 1.161872532430908
# ENTERTAINMENT: 0.9588268471517203
# LIBRARIES_AND_DEMO: 0.9362662154540328
# AUTO_AND_VEHICLES: 0.924985899605189
# HOUSE_AND_HOME: 0.8234630569655951
# WEATHER: 0.8009024252679076
# EVENTS: 0.7106598984771574
# PARENTING: 0.6542583192329385
# ART_AND_DESIGN: 0.6429780033840948
# COMICS: 0.6204173716864072
# BEAUTY: 0.5978567399887197

# %% [markdown]
# The most common category in android dataset is 'Family' which accounts for almost 19% of the apps. This is then followed closely by Game, Tools, and Business apps.
# Based on this and the genre table, we can see that practical apps are more prevalent in Google Play.

# %%
display_table(ios_final, ios_hi['prime_genre'])
# Out:
# Games: 58.16263190564867
# Entertainment: 7.883302296710118
# Photo & Video: 4.9658597144630665
# Education: 3.662321539416512
# Social Networking: 3.2898820608317814
# Shopping: 2.60707635009311
# Utilities: 2.5139664804469275
# Sports: 2.1415270018621975
# Music: 2.0484171322160147
# Health & Fitness: 2.0173805090006205
# Productivity: 1.7380509000620732
# Lifestyle: 1.5828677839851024
# News: 1.3345747982619491
# Travel: 1.2414649286157666
# Finance: 1.1173184357541899
# Weather: 0.8690254500310366
# Food & Drink: 0.8069522036002483
# Reference: 0.5586592178770949
# Business: 0.5276225946617008
# Book: 0.4345127250155183
# Navigation: 0.186219739292365
# Medical: 0.186219739292365
# Catalogs: 0.12414649286157665

# %% [markdown]
# For the iOS dataset, we can see that among the free English apps, more than a half (58.16%) are games. Entertainment apps are close to 8%, followed by photo and video apps, which are close to 5%. Only 3.66% of the apps are designed for education, followed by social networking apps which amount for 3.29% of the apps in our data set.
# <br>
# The general impression is that App Store (Free English apps) are dominated by apps designed for fun(games, entertainment, photo and video, social network etc.) while practical apps are more rare.

# %% [markdown]
# Up to this point, we found that the App Store is dominated by apps designed for fun, while Google Play shows a more balanced landscape of both practical and for-fun apps. Now we'd like to get an idea about the kind of apps that have most users.

# %% [markdown]
# ## Most Popular Apps by Genre on the App Store

# %% [markdown]
# We will create another frequency table in terms of the number of user ratings.

# %%
unique_genres = freq_table(ios_final, ios_hi['prime_genre'])
max_avg = (0, '')
for genre in unique_genres:
  total = 0
  len_genre = 0
  for app in ios_final:
    genre_app = app[ios_hi['prime_genre']]
    if genre_app == genre:
      ratings_count = float(app[ios_hi['rating_count_tot']])
      total += ratings_count
      len_genre += 1
  avg_n_ratings = total / len_genre
  print(f'{genre}: {avg_n_ratings}')
  if max_avg[0] < avg_n_ratings:
    max_avg = (avg_n_ratings, genre)
print(f'Highest Average reviews: {max_avg}')
# Out:
# Social Networking: 71548.34905660378
# Photo & Video: 28441.54375
# Games: 22788.6696905016
# Music: 57326.530303030304
# Reference: 74942.11111111111
# Health & Fitness: 23298.015384615384
# Weather: 52279.892857142855
# Utilities: 18684.456790123455
# Travel: 28243.8
# Shopping: 26919.690476190477
# News: 21248.023255813954
# Navigation: 86090.33333333333
# Lifestyle: 16485.764705882353
# Entertainment: 14029.830708661417
# Food & Drink: 33333.92307692308
# Sports: 23008.898550724636
# Book: 39758.5
# Finance: 31467.944444444445
# Education: 7003.983050847458
# Productivity: 21028.410714285714
# Business: 7491.117647058823
# Catalogs: 4004.0
# Medical: 612.0
# Highest Average reviews: (86090.33333333333, 'Navigation')

# %% [markdown]
# On average, navigation apps have the highest number of user reviews, but this figure is heavily influenced by Waze and Google Maps, which have close to half a miliion user reviews together:

# %%
for app in ios_final:
  if app[ios_hi['prime_genre']] == 'Navigation':
    print(f'{app[1]}:{app[ios_hi["rating_count_tot"]]}')
# Out:
# Waze - GPS Navigation, Maps & Real-time Traffic:345046
# Google Maps - Navigation & Transit:154911
# Geocaching®:12811
# CoPilot GPS – Car Navigation & Offline Maps:3582
# ImmobilienScout24: Real Estate Search in Germany:187
# Railway Route Search:5

# %% [markdown]
# The same pattern applies to social networking apps, where the average number is heavily influenced by a few giants like Facebook, Pinterest, etc. Same applies to music apps, where a few big players like Pandora, Spotify and Shazam heavily influence the average number.
# <br>
# The other app genre with high average is the Reference.

# %%
for app in ios_final:
  if app[ios_hi['prime_genre']] == 'Reference':
    print(f'{app[1]}:{app[ios_hi["rating_count_tot"]]}')
# Out:
# Bible:985920
# Dictionary.com Dictionary & Thesaurus:200047
# Dictionary.com Dictionary & Thesaurus for iPad:54175
# Google Translate:26786
# Muslim Pro: Ramadan 2017 Prayer Times, Azan, Quran:18418
# New Furniture Mods - Pocket Wiki & Game Tools for Minecraft PC Edition:17588
# Merriam-Webster Dictionary:16849
# Night Sky:12122
# City Maps for Minecraft PE - The Best Maps for Minecraft Pocket Edition (MCPE):8535
# LUCKY BLOCK MOD ™ for Minecraft PC Edition - The Best Pocket Wiki & Mods Installer Tools:4693
# GUNS MODS for Minecraft PC Edition - Mods Tools:1497
# Guides for Pokémon GO - Pokemon GO News and Cheats:826
# WWDC:762
# Horror Maps for Minecraft PE - Download The Scariest Maps for Minecraft Pocket Edition (MCPE) Free:718
# VPN Express:14
# Real Bike Traffic Rider Virtual Reality Glasses:8
# 教えて!goo:0
# Jishokun-Japanese English Dictionary & Translator:0

# %% [markdown]
# This may present a great opportunity since Reference Apps is not that saturated compared to Entertainment apps which has greater competition.

# %% [markdown]
# ## Most Popular Apps by Genre on Google Play
# For the Google Play market, we have data about the number of installs, so we should be able to get a clearer picture about genre popularity. However, the install numbers are not precise.

# %%
display_table(android_final, an_hi['Installs'])
# Out:
# 1,000,000+: 15.724760293288211
# 100,000+: 11.551043429216017
# 10,000,000+: 10.547095318668923
# 10,000+: 10.197405527354766
# 1,000+: 8.403835307388608
# 100+: 6.91483361534123
# 5,000,000+: 6.824591088550479
# 500,000+: 5.561195713479977
# 50,000+: 4.771573604060913
# 5,000+: 4.512126339537507
# 10+: 3.542019176536943
# 500+: 3.248730964467005
# 50,000,000+: 2.3011844331641287
# 100,000,000+: 2.131979695431472
# 50+: 1.9176536943034406
# 5+: 0.7896221094190639
# 1+: 0.5076142131979695
# 500,000,000+: 0.2707275803722504
# 1,000,000,000+: 0.2256063169768754
# 0+: 0.04512126339537507
# 0: 0.011280315848843767

# %% [markdown]
# The problem with the data is that is not precise, we are not sure whether an app with 100,000+ installs have 100,000 installs instead of 199,000. Fortunately for our case, we do not require the precise count, we only need to get an idea of what app category attracts most users.

# %% [markdown]
# We will leave the numbers as they are, which means that an app with 100,000+ installs has 100,000 installs.

# %%
android_category = {row[an_hi['Category']]:[0,0] for row in android_final}
android_category
# Out:
# {'ART_AND_DESIGN': [0, 0],
#  'AUTO_AND_VEHICLES': [0, 0],
#  'BEAUTY': [0, 0],
#  'BOOKS_AND_REFERENCE': [0, 0],
#  'BUSINESS': [0, 0],
#  'COMICS': [0, 0],
#  'COMMUNICATION': [0, 0],
#  'DATING': [0, 0],
#  'EDUCATION': [0, 0],
#  'ENTERTAINMENT': [0, 0],
#  'EVENTS': [0, 0],
#  'FINANCE': [0, 0],
#  'FOOD_AND_DRINK': [0, 0],
#  'HEALTH_AND_FITNESS': [0, 0],
#  'HOUSE_AND_HOME': [0, 0],
#  'LIBRARIES_AND_DEMO': [0, 0],
#  'LIFESTYLE': [0, 0],
#  'GAME': [0, 0],
#  'FAMILY': [0, 0],
#  'MEDICAL': [0, 0],
#  'SOCIAL': [0, 0],
#  'SHOPPING': [0, 0],
#  'PHOTOGRAPHY': [0, 0],
#  'SPORTS': [0, 0],
#  'TRAVEL_AND_LOCAL': [0, 0],
#  'TOOLS': [0, 0],
#  'PERSONALIZATION': [0, 0],
#  'PRODUCTIVITY': [0, 0],
#  'PARENTING': [0, 0],
#  'WEATHER': [0, 0],
#  'VIDEO_PLAYERS': [0, 0],
#  'NEWS_AND_MAGAZINES': [0, 0],
#  'MAPS_AND_NAVIGATION': [0, 0]}

# %%
for row in android_final:
  cat = row[an_hi['Category']]
  installs = row[an_hi['Installs']]
  installs = installs.replace('+', '')
  installs = installs.replace(',', '')
  android_category[cat][0] += float(installs)
  android_category[cat][1] += 1

# %%
android_category
# Out:
# {'ART_AND_DESIGN': [113221100.0, 57],
#  'AUTO_AND_VEHICLES': [53080061.0, 82],
#  'BEAUTY': [27197050.0, 53],
#  'BOOKS_AND_REFERENCE': [1665884260.0, 190],
#  'BUSINESS': [696902090.0, 407],
#  'COMICS': [44971150.0, 55],
#  'COMMUNICATION': [11036906201.0, 287],
#  'DATING': [140914757.0, 165],
#  'EDUCATION': [188850000.0, 103],
#  'ENTERTAINMENT': [989460000.0, 85],
#  'EVENTS': [15973160.0, 63],
#  'FINANCE': [455163132.0, 328],
#  'FOOD_AND_DRINK': [211738751.0, 110],
#  'HEALTH_AND_FITNESS': [1143548402.0, 273],
#  'HOUSE_AND_HOME': [97202461.0, 73],
#  'LIBRARIES_AND_DEMO': [52995810.0, 83],
#  'LIFESTYLE': [497484429.0, 346],
#  'GAME': [13436869450.0, 862],
#  'FAMILY': [6193895690.0, 1676],
#  'MEDICAL': [37732344.0, 313],
#  'SOCIAL': [5487861902.0, 236],
#  'SHOPPING': [1400338585.0, 199],
#  'PHOTOGRAPHY': [4656269815.0, 262],
#  'SPORTS': [1095230683.0, 301],
#  'TRAVEL_AND_LOCAL': [2894704086.0, 207],
#  'TOOLS': [8101043474.0, 750],
#  'PERSONALIZATION': [1529235888.0, 294],
#  'PRODUCTIVITY': [5791629314.0, 345],
#  'PARENTING': [31471010.0, 58],
#  'WEATHER': [360288520.0, 71],
#  'VIDEO_PLAYERS': [3931731720.0, 159],
#  'NEWS_AND_MAGAZINES': [2368196260.0, 248],
#  'MAPS_AND_NAVIGATION': [503060780.0, 124]}

# %% [markdown]
# Let's print the average installs

# %%
for category, values in android_category.items():
  print(f'{category}: {values[0]/values[1]}')
# Out:
# ART_AND_DESIGN: 1986335.0877192982
# AUTO_AND_VEHICLES: 647317.8170731707
# BEAUTY: 513151.88679245283
# BOOKS_AND_REFERENCE: 8767811.894736841
# BUSINESS: 1712290.1474201474
# COMICS: 817657.2727272727
# COMMUNICATION: 38456119.167247385
# DATING: 854028.8303030303
# EDUCATION: 1833495.145631068
# ENTERTAINMENT: 11640705.88235294
# EVENTS: 253542.22222222222
# FINANCE: 1387692.475609756
# FOOD_AND_DRINK: 1924897.7363636363
# HEALTH_AND_FITNESS: 4188821.9853479853
# HOUSE_AND_HOME: 1331540.5616438356
# LIBRARIES_AND_DEMO: 638503.734939759
# LIFESTYLE: 1437816.2687861272
# GAME: 15588015.603248259
# FAMILY: 3695641.8198090694
# MEDICAL: 120550.61980830671
# SOCIAL: 23253652.127118643
# SHOPPING: 7036877.311557789
# PHOTOGRAPHY: 17772022.194656488
# SPORTS: 3638640.1428571427
# TRAVEL_AND_LOCAL: 13984077.710144928
# TOOLS: 10801391.298666667
# PERSONALIZATION: 5201482.6122448975
# PRODUCTIVITY: 16787331.344927534
# PARENTING: 542603.6206896552
# WEATHER: 5074486.197183099
# VIDEO_PLAYERS: 24727872.452830188
# NEWS_AND_MAGAZINES: 9549178.467741935
# MAPS_AND_NAVIGATION: 4056941.7741935486
